# %%
# %matplotlib inline
import numpy as np

# %%
from dsets_classification import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(candidateInfo_list))
print(positiveInfo_list[0])
# Out:
# 550896
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.82725575, 85.37992457, -109.74672379999998))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0   1.0 mm
#  100   1.0 mm
#  200   1.0 mm
#  300   1.0 mm
#  400   1.0 mm
#  500   1.0 mm
#  600   1.0 mm
#  700   1.0 mm
#  800   1.0 mm
#  900   1.0 mm
# 1000   1.0 mm
# 1100   1.0 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.82725575, 85.37992457, -109.74672379999998))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(47.67105722, 37.64251989, -99.89039388))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-46.94966448, 72.63645381, -95.64452131))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=27.07544345, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(-103.13251120000001, -5.774672551, -206.3554703))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=25.87269662, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.177086402277715068525592995222', center_xyz=(-66.47429649, 58.43968307, -109.3643906))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=25.23320204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.511347030803753100045216493273', center_xyz=(60.77506053, 74.1239696, -214.7823466))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=24.78201705, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.183982839679953938397312236359', center_xyz=(-46.59430055, 64.33901696, -149.78711769999998))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=24.77327957, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268', center_xyz=(91.41858153, -21.56714696, -257.79889590000005))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=24.66335961, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.316900421002460665752357657094', center_xyz=(-97.41069879, -44.65572813, -143.88672240000002))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=24.28186352, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.153985109349433321657655488650', center_xyz=(-32.44901873, 49.38239307, -60.31881666))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.556818181, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300270516469599170290456821227', center_xyz=(-64.08984827, -185.1943695, -176.461318))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.5309737610000003, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.776800177074349870648765614630', center_xyz=(-84.41936241, 5.4010254170000005, -181.75))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.439486702, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.179162671133894061547290922949', center_xyz=(-50.33006209, 88.30887267, -677.3324660000001))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.4312838080000003, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630', center_xyz=(-143.0264631, -23.42697971, -178.5216354))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.4233417189999997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.176638348958425792989125209419', center_xyz=(97.58296617, 41.96482868, -79.81459274))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.3939854639999996, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124822907934319930841506266464', center_xyz=(31.31603013, -141.7597373, -93.9202978))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.3415640989999997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630', center_xyz=(122.74030790000002, -3.364329503, -222.39426349999997))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.297324878, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.504845428620607044098514803031', center_xyz=(-101.0307142, -45.9959128, -151.0599558))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.270466947, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.182192086929819295877506541021', center_xyz=(56.58885682, -67.46153204, -77.34666348))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.253443196, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.151764021165118974848436095034', center_xyz=(-64.867508, 103.6062633, -620.0340436))
# CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=6.378436317, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(145.967465, -161.19763419999998, -312.0713474))

# %%
np.histogram(diameter_list)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# (array([   0,    0,    0,    0,    0, 1182,    0,    0,    0,    0]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]))

# %%
from vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2022-07-24 19:45:46,945 INFO     pid:11534 dsets_classification:295:__init__ <dsets_classification.LunaDataset object at 0x7fb6fd758f70>: 550896 training samples, 549714 neg, 1182 pos, unbalanced ratio
# 0 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=6.313681857000001, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227885601428639043345478571594', center_xyz=(-79.51333218, 120.4823722, -68.3844107))
# 1 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.4233417189999997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.176638348958425792989125209419', center_xyz=(97.58296617, 41.96482868, -79.81459274))
# 2 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.2080745010000005, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.324567010179873305471925391582', center_xyz=(-35.50220052, 12.42447242, -98.52928857))
# 3 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.642186102999999, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478', center_xyz=(32.58870589, -102.4937764, -88.46395383))
# 4 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=8.566001555, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.178680586845223339579041794709', center_xyz=(65.13766410000001, 43.75788979, -236.47107459999998))
# 5 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=7.663782425, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.275755514659958628040305922764', center_xyz=(-90.94045378, -230.2193214, -217.07148199999997))
# 6 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.108290964, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.168833925301530155818375859047', center_xyz=(-106.6074186, 13.30759394, -194.0673055))
# 7 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.973944221, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780', center_xyz=(144.34966819999997, -136.35111630000003, -435.821845))
# 8 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.143870035, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.168833925301530155818375859047', center_xyz=(95.99267245, 75.81091807, -193.0071743))
# 9 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.393756108, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001
series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.242624386080831911167122628616', center_xyz=(-70.05203824, -177.28636730000002, -196.01784730000003))
# 79 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.492434135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.125124219978170516876304987559', center_xyz=(124.37043899999999, -106.01149550000001, -208.2958333))
# 80 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=7.88580587, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.479402560265137632920333093071', center_xyz=(-152.3569324, -22.28584934, -274.372396))
# 81 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=7.60446251, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596873065041988320084', center_xyz=(44.01647614, -7.920203139, -249.6876651))
# 82 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=3.899770457, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.217697417596902141600884006982', center_xyz=(112.2326686, 9.722890567, -197.4920729))
# 83 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=13.80566396, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.257383535269991165447822992959', center_xyz=(-47.10027725, 55.21237511, -132.715981))
# 84 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.129855377, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.252814707117018427472206147014', center_xyz=(61.32976859, 84.76491799, -250.9065563))
# 85 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.277166591, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798', center_xyz=(-74.95237164, 46.90988268, -285.5115615))
# 86 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.786347814, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208', center_xyz=(69.63901724, -140.94458590000002, 876.3744957))
# 87 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.506689862, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.183184435049555024219115904825', center_xyz=(-71.70939018, -47.08972918, -218.4168486))
# 88 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=11.16379761, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.214252223927572015414741039150', center_xyz=(-42.47036236, 9.63938615, -67.76005548))
# 89 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.8668673479999995, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.265775376735520890308424143898', center_xyz=(0.378580731, 213.6507752, -676.9320690000001))
# 90 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=7.401764599, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.179162671133894061547290922949', center_xyz=(134.4219361, 86.57701746, -762.5944357999999))
# 91 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=10.93827513, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-55.18838267, 174.3893763, -405.7348248))
# 92 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=6.1976770839999995, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.239358021703233250639913775427', center_xyz=(52.03768945, -57.49443854, -179.1694878))
# 93 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.738267951, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.218476624578721885561483687176', center_xyz=(-115.6455979, -38.82732218, -109.6419395))
# 94 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.355658900000001, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295249119452142211437', center_xyz=(59.89735907, 41.71051844, -96.24057315))
# 95 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=5.304621719, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188059920088313909273628445208', center_xyz=(-110.5020624, 84.49831867, 1506.369708))
# 96 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=8.117918353, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.975426625618184773401026809852', center_xyz=(52.99602068, 85.06797975, -105.4608119))
# 97 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=False, diameter_mm=4.793159505, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.259124675432205040899951626253', center_xyz=(-59.76229837, -62.261798899999995, -167.15663899999998))
# 98 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=18.86783511, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.323408652979949774528873200770', center_xyz=(74.72764672, 30.75813083, -101.31159050000001))
# 99 CandidateInfoTuple(isNodule_bool=True, hasAnnotation_bool=True, isMal_bool=True, diameter_mm=5.556944532, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.294188507421106424248264912111', center_xyz=(-84.56144675, 53.32378035, -281.9974642))

# %%
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2022-07-24 19:45:52,376 INFO     pid:11534 dsets_classification:295:__init__ <dsets_classification.LunaDataset object at 0x7fb7b47aa400>: 0 training samples, 0 neg, 0 pos, unbalanced ratio
# Warning: no positive samples found; using first negative sample.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <module>
#       1 series_uid = positiveSample_list[11][2]
# ----> 2 showCandidate(series_uid)
#
# File ~/OneDrive/github/Ent-to-end-detector-for-lung-cancer/data_exploration/vis.py:36, in showCandidate(series_uid, batch_ndx, **kwargs)
#      33         print("Warning: no positive samples found; using first negative sample.")
#      34         batch_ndx = 0
# ---> 36 ct = Ct(series_uid)
#      37 ct_t, pos_t, series_uid, center_irc = ds[batch_ndx]
#      38 ct_a = ct_t[0].numpy()
#
# File ~/OneDrive/github/Ent-to-end-detector-for-lung-cancer/data_exploration/dsets_classification.py:100, in Ct.__init__(self, series_uid)
#      99 def __init__(self, series_uid):
# --> 100     mhd_path = glob.glob(
#     101         '../../LUNA/subset*/{}.mhd'.format(series_uid)   # We don't care to track which subset a given series_uid is in,
#     102                                                             # so we wildcard the subset
#     103     )[0]
#     105     ct_mhd = sitk.ReadImage(mhd_path)   # sitk.ReadImage implicitly consumes the .raw file in addition to the passed-in
#     106                                         # .mhd file.
#
# IndexError: list index out of range

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2022-07-24 18:41:56,839 INFO     pid:27531 dsets:170:__init__ <dsets.LunaDataset object at 0x7f9fdb813c10>: 1061 training samples
# <img src="data:image/png;base64,..." width="2160">
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 0 False [0]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2022-07-24 19:46:13,206 INFO     pid:11534 dsets_classification:295:__init__ <dsets_classification.LunaDataset object at 0x7fb6fa4b77f0>: 605 training samples, 604 neg, 1 pos, unbalanced ratio
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <module>
#       1 series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
# ----> 2 showCandidate(series_uid)
#
# File ~/OneDrive/github/Ent-to-end-detector-for-lung-cancer/data_exploration/vis.py:37, in showCandidate(series_uid, batch_ndx, **kwargs)
#      34         batch_ndx = 0
#      36 ct = Ct(series_uid)
# ---> 37 ct_t, pos_t, series_uid, center_irc = ds[batch_ndx]
#      38 ct_a = ct_t[0].numpy()
#      40 fig = plt.figure(figsize=(30, 50))
#
# ValueError: too many values to unpack (expected 4)

# %%
LunaDataset()[0]
# Out:
# 2022-07-24 19:46:19,490 INFO     pid:11534 dsets_classification:295:__init__ <dsets_classification.LunaDataset object at 0x7fb6fa42ae20>: 550896 training samples, 549714 neg, 1182 pos, unbalanced ratio
# (tensor([[[[ -901.,  -837.,  -956.,  ...,  -888., -1000.,  -922.],
#            [ -979.,  -846.,  -892.,  ..., -1000., -1000.,  -999.],
#            [ -721.,  -858.,  -738.,  ...,  -921.,  -740.,  -902.],
#            ...,
#            [ -758.,  -752.,  -889.,  ...,  -780.,  -628.,   -83.],
#            [-1000.,  -942.,  -751.,  ...,  -805.,  -607.,  -186.],
#            [ -796.,  -988.,  -933.,  ...,  -913.,  -282.,  -123.]],
#
#           [[ -838.,  -902.,  -834.,  ..., -1000., -1000., -1000.],
#            [ -863.,  -778.,  -781.,  ..., -1000., -1000., -1000.],
#            [ -722.,  -693.,  -860.,  ..., -1000.,  -959., -1000.],
#            ...,
#            [ -910.,  -924.,  -984.,  ...,  -856.,  -926.,  -587.],
#            [ -825.,  -752.,  -694.,  ...,  -796.,  -843.,  -346.],
#            [ -805.,  -950., -1000.,  ...,  -995.,  -669.,  -149.]],
#
#           [[ -732.,  -665.,  -691.,  ..., -1000., -1000., -1000.],
#            [ -891.,  -800.,  -809.,  ...,  -970., -1000.,  -936.],
#            [ -813.,  -670.,  -779.,  ..., -1000.,  -999., -1000.],
#            ...,
#            [ -927., -1000.,  -926.,  ...,  -796.,  -733.,  -881.],
#            [ -815.,  -804.,  -835.,  ...,  -793.,  -837.,  -797.],
#            [ -840.,  -956., -1000.,  ...,  -889.,  -963.,  -658.]],
#
#           ...,
#
#           [[ -841.,  -668.,  -708.,  ...,  -847.,  -894.,  -848.],
#            [ -732.,  -866.,  -931.,  ...,  -887.,  -750.,  -843.],
#            [-1000.,  -823.,  -726.,  ...,  -933.,  -825.,  -707.],
#            ...,
#            [ -877.,  -656.,  -551.,  ...,   -24.,    22.,    86.],
#            [ -592.,  -731.,  -781.,  ...,   -65.,  -172.,   -65.],
#            [ -925.,  -626.,  -605.,  ...,    28.,   -58.,  -127.]],
#
#           [[ -807.,  -621.,  -727.,  ...,  -889.,  -948., -1000.],
#            [ -655.,  -860.,  -747.,  ...,  -875.,  -776.,  -844.],
#            [-1000.,  -928.,  -977.,  ...,  -824.,  -798.,  -732.],
#            ...,
#            [ -988.,  -968.,  -834.,  ...,   -97.,   144.,   189.],
#            [ -665.,  -750.,  -603.,  ...,    21.,    48.,    58.],
#            [ -813.,  -930.,  -839.,  ...,   -19.,  -164.,  -349.]],
#
#           [[ -675.,  -742.,  -676.,  ...,  -740.,  -738.,  -914.],
#            [ -874., -1000.,  -903.,  ...,  -962.,  -910.,  -924.],
#            [ -699.,  -740.,  -820.,  ...,  -779.,  -614.,  -834.],
#            ...,
#            [ -897.,  -780.,  -674.,  ...,  -268.,  -341.,  -267.],
#            [ -698.,  -811.,  -963.,  ...,   126.,   128.,   118.],
#            [ -993.,  -916.,  -807.,  ...,   -77.,  -152.,  -228.]]]]),
#  tensor([1, 0]),
#  0,
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.306140003699110313373771452136',
#  tensor([ 91, 326, 203]))

# %%
import numpy as np
import ipyvolume as ipv
V = np.zeros((128,128,128)) # our 3d array
# outer box
V[30:-30,30:-30,30:-30] = 0.75
V[35:-35,35:-35,35:-35] = 0.0
# inner box
V[50:-50,50:-50,50:-50] = 0.25
V[55:-55,55:-55,55:-55] = 0.0
ipv.quickvolshow(V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1)
# Out:
# 2022-07-24 19:46:28,786 INFO     pid:11534 numexpr.utils:160:_init_num_threads NumExpr defaulting to 8 threads.
# /home/silviobaratto/anaconda3/lib/python3.8/site-packages/ipyvolume/serialize.py:92: RuntimeWarning: invalid value encountered in true_divide
#   gradient = gradient / np.sqrt(gradient[0] ** 2 + gradient[1] ** 2 + gradient[2] ** 2)
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, step=0.0…

# %%
ct = getCt(series_uid)
ipv.quickvolshow(ct.hu_a, level=[0.25, 0.5, 0.9], opacity=0.1, level_width=0.1, data_min=-1000, data_max=1000)
# Out:
# /home/silviobaratto/anaconda3/lib/python3.8/site-packages/ipyvolume/widgets.py:241: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data_view = self.data_original[view]
# /home/silviobaratto/anaconda3/lib/python3.8/site-packages/ipyvolume/utils.py:208: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   data = (data[slices1] + data[slices2]) / 2
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, step=0.0…

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from dsets_classification import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)
# Out:
# /tmp/ipykernel_11534/2460116618.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]

# %%
bones = ct.hu_a * (ct.hu_a > 1.5)
lungs = ct.hu_a * air_mask
ipv.figure()
ipv.pylab.volshow(bones + lungs, level=[0.17, 0.17, 0.23], data_min=100, data_max=900)
ipv.show()
# Out:
# VBox(children=(VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.17, max=1.0, step=0.0…
